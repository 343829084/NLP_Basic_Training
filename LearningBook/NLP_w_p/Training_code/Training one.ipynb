# %%
import nltk
from nltk import book
12/(4+1)#1
# Out:
# 2.4

# %%
26**10#2
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %%
['Monty','Python']*20#3
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %%
from nltk.book import *
len(nltk.book.text4)#4
len(set(text4))
# Out:
# 9754

# %%
#5多样性越大越丰富

# %%
text2.dispersion_plot(["Elinor","Marianne","Edward","Willoughby"])#6

# %%
text5.collocations()#7
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
len(set(text4))#8求文本的词数
set(text4)
len(text4)
# Out:
# 145735

# %%
my_string = "My String"#9.a

# %%
my_string
# Out:
# 'My String'

# %%
print(my_string)
# Out:
# My String

# %%
my_string*3#9.b
# Out:
# 'My StringMy StringMy String'

# %%
((my_string+" ")*3).strip()
# Out:
# 'My String My String My String'

# %%
my_sent=["My","sent"]

# %%
' '.join(my_sent)#10.a
# Out:
# 'My sent'

# %%
my_sent[1].split("e")#10.b
# Out:
# ['s', 'nt']

# %%
phrase1 = "aa"
phrase2 = "aaa"#11

# %%
len(phrase1)+len(phrase2)
# Out:
# 5

# %%
len(phrase1+phrase2)
# Out:
# 5

# %%
#12忽略

# %%
sent1[2][2]#13
# Out:
# 'h'

# %%
sent1[2][1]#第某个词的第几个字符
# Out:
# 's'

# %%
sent3.index("the")
# Out:
# 1

# %%
[i for i in range(len(sent3))  if sent3[i]=="the"]#14
# Out:
# [1, 5, 8]

# %%
sorted([i for i in text5 if i.startswith("b")])#15
# Out:
# ['b',
#  'b',
#  'b',
#  'b',
#  'b',
#  'b',
#  'b-day',
#  'b/c',
#  'b4',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babes',
#  'babes',
#  'babes',
#  'babi',
#  'babi',
#  'babies',
#  'babies',
#  'babiess',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
# ...

# %%
range(10)#16
range(10,20)
range(10,20,2)
# Out:
# range(10, 20, 2)

# %%
text9.index("sunset")#17
# Out:
# 629

# %%
text9[613:633]
# Out:
# ['CHAPTER',
#  'I',
#  'THE',
#  'TWO',
#  'POETS',
#  'OF',
#  'SAFFRON',
#  'PARK',
#  'THE',
#  'suburb',
#  'of',
#  'Saffron',
#  'Park',
#  'lay',
#  'on',
#  'the',
#  'sunset',
#  'side',
#  'of',
#  'London']

# %%
def word_set(sent):
    return sorted(set(sent))#18

# %%
a = map(word_set,[sent1,sent2,sent3,sent4,sent5,sent6,sent7,sent8])

# %%
for i in a:
    print(i)
# Out:
# ['.', 'Call', 'Ishmael', 'me']
# ['.', 'Dashwood', 'Sussex', 'The', 'been', 'family', 'had', 'in', 'long', 'of', 'settled']
# ['.', 'God', 'In', 'and', 'beginning', 'created', 'earth', 'heaven', 'the']
# ['-', ':', 'Citizens', 'Fellow', 'House', 'Representatives', 'Senate', 'and', 'of', 'the']
# ['I', 'JOIN', 'PMing', 'a', 'have', 'lol', 'me', 'people', 'problem', 'to', 'with']
# ['!', '1', ':', 'ARTHUR', 'KING', 'SCENE', 'Whoa', '[', ']', 'clop', 'there', 'wind']
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken', 'a', 'as', 'board', 'director', 'join', 'nonexecutive', 'old', 'the', 'will', 'years']
# [',', '.', '25', 'MALE', 'SEXY', 'attrac', 'discreet', 'encounters', 'for', 'lady', 'older', 'seeks', 'single']

# %%
#19第二行比较大，小写后的词还没过滤

# %%
def test(num,str):
    if num ==1:
        if str.isupper():
            return "ok"#20
    else:
        if not str.islower():
            return "ok"

# %%
test(1,"Ssd")#第一个必须全是大写，第二个包含大写字母就可以了

# %%
text2[-2:]#21
# Out:
# ['THE', 'END']

# %%
a = [i for i in text5 if len(i)==4]#22

# %%
sorted([i for i in FreqDist(text5).keys() if i in a])
# Out:
# ['!!!!',
#  '!!!.',
#  '!...',
#  '!???',
#  '"...',
#  '####',
#  '((((',
#  '))))',
#  ',,,,',
#  '.. .',
#  '....',
#  '.op.',
#  '1.98',
#  '1.99',
#  '100%',
#  '10th',
#  '1200',
#  '1299',
#  '18ST',
#  '1900',
#  '1930',
#  '1980',
#  '1985',
#  '1996',
#  '1cos',
#  '2006',
#  '2:55',
#  '2DAY',
#  '2Pac',
#  '39.3',
#  '3:45',
#  '4.20',
#  '45.5',
#  '4:03',
#  '64.8',
#  '6:38',
#  '6:41',
#  '6:51',
#  '6:53',
#  '7:45',
#  '9.53',
#  '98.5',
#  '98.6',
#  '9:10',
#  ':o *',
#  '; ..',
#  '<---',
#  "<3's",
#  '<333',
#  '<<<<',
#  '<~~~',
#  '>:->',
#  '?!?!',
#  '??!!',
#  '????',
#  'AKDT',
#  'AKST',
#  'AWAY',
#  'Ahhh',
#  'Away',
#  'Awww',
#  'Back',
#  'Been',
#  'Bone',
#  'Born',
#  'Boyz',
#  'CALI',
#  'CAPS',
#  'CHAT',
#  'COME',
#  'Came',
#  'Care',
#  'Chat',
#  'Chop',
#  'City',
#  'Come',
#  'Cool',
#  'Ctrl',
#  'Cute',
#  'DAMN',
#  'DING',
#  'DOES',
#  'DONT',
#  'Damn',
#  'Dang',
#  'Dawn',
#  'Days',
#  'Deep',
#  'Does',
#  'Dood',
# ...

# %%
for i in text6:
    if i.isupper():
        print(i)#23
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %%
[i for i in set(text6) if i.endswith("ize") and i.find("z") and i.find("pt") and i.title()]#24
# Out:
# []

# %%
sent = ["she","sells","sea","shells","by","the","sea","shore"]#25

# %%
[i for i in sent if i.startswith("sh")]#25.a
# Out:
# ['she', 'shells', 'shore']

# %%
[i for i in sent if len(i)>=4]#25.b
# Out:
# ['sells', 'shells', 'shore']

# %%
a = sum([len(w) for w in text1])#26求所有字长

# %%
a/len(text1)
# Out:
# 3.830411128023649

# %%
def vocab_size(text):
    return len(text)#27

# %%
vocab_size(text1)
# Out:
# 260819

# %%
def percent(word,text):
    return 100*text.count(word)/len(text)#28

# %%
set(sent3)<set(text1)#29主要是去重使用
# Out:
# True
